# %%
cd ../../../
# Out:
# /Users

# %%
pushd '/Users/inesllado/Documents/Ironhack/lab_/lab-customer-analysis-round-3/files_for_lab/csv_files'
# Out:
# /Users/inesllado/Documents/Ironhack/lab_/lab-customer-analysis-round-3/files_for_lab/csv_files
# ['/Users', '/Users', '/Users', '/Users']

# %%
ls
# Out:
# marketing_customer_analysis.csv*

# %%
import pandas as pd

# %%
data = pd.read_csv('marketing_customer_analysis.csv')

# %%
data #Show DataFrame info:
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
data.describe() #Describe DataFrame:
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
data ['Response'].value_counts()
# Out:
# No     7826
# Yes    1308
# Name: Response, dtype: int64

# %%
data.Response
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 9129     No
# 9130    Yes
# 9131     No
# 9132     No
# 9133     No
# Name: Response, Length: 9134, dtype: object

# %%
data[['Response', 'Sales Channel']]
# Out:
#      Response Sales Channel
# 0          No         Agent
# 1          No         Agent
# 2          No         Agent
# 3          No   Call Center
# 4          No         Agent
# ...       ...           ...
# 9129       No           Web
# 9130      Yes        Branch
# 9131       No        Branch
# 9132       No        Branch
# 9133       No   Call Center
#
# [9134 rows x 2 columns]

# %%
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %%
# %matplotlib inline

# %%
data ['Response'].value_counts()
# Out:
# No     7826
# Yes    1308
# Name: Response, dtype: int64

# %%
plot
# Out:
#    Response
# 0  Response

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import seaborn as sns

# %%
data.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
#Show a plot of the total number of responses // above shows the total number of responses.

# %%
data['Response'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
response_by_sales = pd.crosstab(data['Response'], data['Sales Channel'])

# %%
response_by_sales
# Out:
# Sales Channel  Agent  Branch  Call Center   Web
# Response
# No              2811    2273         1573  1169
# Yes              666     294          192   156

# %%
response_by_sales
# Out:
# Sales Channel  Agent  Branch  Call Center   Web
# Response
# No              2811    2273         1573  1169
# Yes              666     294          192   156

# %%
barplt = response_by_sales.plot.bar(rot=0)

#Show a plot of the response rate by the sales channel:

# %%
#testing if I can change the values around

response_by_sales2 = pd.crosstab(data['Sales Channel'],data['Response'])

# %%
barplt = response_by_sales2.plot.bar(rot=0)

#Final plot for response rate by the sales channel:

# %%
#Show a plot of the response rate by the total claim amount.

response_by_totalclaim = pd.crosstab(data['Total Claim Amount'], data['Response'])

# %%
response_by_totalclaim
# Out:
# Response            No  Yes
# Total Claim Amount
# 0.099007             1    0
# 0.382107             1    0
# 0.423310             1    0
# 0.517753             1    0
# 0.769185             1    0
# ...                 ..  ...
# 2345.413441          1    0
# 2452.894264          1    0
# 2552.343856          1    0
# 2759.794354          1    0
# 2893.239678          1    0
#
# [5106 rows x 2 columns]

# %%
response_by_totalclaim.descibe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-166-fff42a02f482> in <module>
# ----> 1 response_by_totalclaim.descibe()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'descibe'

# %%
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import numpy as np

# %%
response_by_totalclaim.shape
# Out:
# (5106, 2)

# %%
plot = response_by_totalclaim.plot(rot=0)

#Show a plot of the response rate by the total claim amount.

# %%
# Show a plot of the response rate by income.

# %%
response_by_income = pd.crosstab(data['Income'], data['Response'])

# %%
response_by_income
# Out:
# Response    No  Yes
# Income
# 0         2119  198
# 10037        1    0
# 10074        1    0
# 10097        1    0
# 10105        1    0
# ...        ...  ...
# 99875        1    0
# 99934        1    0
# 99960        1    0
# 99961        1    0
# 99981        1    0
#
# [5694 rows x 2 columns]

# %%
plot = response_by_income.plot(rot=0)

# %%
response_by_income2 = pd.crosstab(data['Response'], data['Income'])

# %%
response_by_income2
# Out:
# Income    0      10037  10074  10097  10105  10147  10180  10194  10211  \
# Response
# No         2119      1      1      1      1      1      1      1      1
# Yes         198      0      0      0      0      0      0      0      0
#
# Income    10237  10269  10275  10312  10334  10337  10375  10384  10458  \
# Response
# No            1      1      1      0      1      1      1      1      1
# Yes           0      0      0      6      0      0      0      0      0
#
# Income    10475  10511  10517  10540  10563  10621  10629  10710  10738  \
# Response
# No            1      1      1      1      1      0      1      1      1
# Yes           0      0      0      0      0      6      0      0      0
#
# Income    10743  10787  10853  10860  10892  11033  11097  11167  11193  \
# Response
# No            1      1      1      1      1      1      1      1      1
# Yes           0      0      0      0      0      0      0      0      0
#
# ...

# %%
scatter = response_by_income.scatter(rot=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-181-d859452b3b4f> in <module>
# ----> 1 scatter = response_by_income.scatter(rot=0)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'scatter'
